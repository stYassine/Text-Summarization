# %%
import re
import bs4 as bs
from urllib.request import urlopen
import nltk
import heapq

# %%
# get source data
source =urlopen("https://en.wikipedia.org/wiki/Global_warming").read()

# %%
# get data from html ( parse html )
soup =bs.BeautifulSoup(source)

# %%
# parse text
text =""

for para in soup.findAll('p'):
    text += para.text
    
text =re.sub(r"\[[0-9]*\]"," ", text)
text =re.sub(r"\s+"," ", text)
clean_text =text.lower()
clean_text =re.sub(r"\W", " ", clean_text)
clean_text =re.sub(r"\d", " ", clean_text)
clean_text =re.sub(r"\s+", " ", clean_text)

# %%
# tokenize text into sentences
sentences =nltk.sent_tokenize(text)

# %%
# get english stopwords
stopwords =nltk.corpus.stopwords.words('english')

# %%
# calculate words score
word2score ={}

for word in nltk.word_tokenize(clean_text):
    if word not in stopwords:
        if word not in word2score.keys():
            word2score[word] = 1
        else:
            word2score[word] += 1
            
for key in word2score.keys():
    word2score[key] =word2score[key] / max(word2score.values())

# %%
word2score
# Out:
# {'global': 0.675,
#  'warming': 0.7666666666666667,
#  'long': 0.06666666666666667,
#  'term': 0.09166666666666666,
#  'rise': 0.11666666666666667,
#  'average': 0.058333333333333334,
#  'temperature': 0.25,
#  'earth': 0.15833333333333333,
#  'climate': 1.0,
#  'system': 0.23943661971830985,
#  'major': 0.11267605633802817,
#  'aspect': 0.014084507042253521,
#  'current': 0.14084507042253522,
#  'change': 1.0,
#  'demonstrated': 0.020833333333333332,
#  'direct': 0.08333333333333333,
#  'measurements': 0.10416666666666667,
#  'various': 0.125,
#  'effects': 0.5208333333333334,
#  'terms': 0.041666666666666664,
#  'often': 0.041666666666666664,
#  'used': 0.14583333333333334,
#  'interchangeably': 0.020833333333333332,
#  'however': 0.08333333333333333,
#  'speaking': 0.020833333333333332,
#  'properly': 0.020833333333333332,
#  'denotes': 0.020833333333333332,
#  'mainly': 0.0625,
#  'human': 0.3541666666666667,
#  'caused': 0.22916666666666666,
#  'increase': 0.4166666666666667,
#  'surface': 0.5,
#  'temperatures': 0.4375,
#  'projected': 0.041666666666666664,
#  'continuation': 0.020833333333333332,
#  'includes': 0.020833333333333332,
#  'changes': 0.4791666666666667,
#  'precipitation': 0.125,
#  'impacts': 0.1875,
#  'differ': 0.041666666666666664,
#  'region': 0.0625,
#  'prehistoric': 0.020833333333333332,
#  'periods': 0.020833333333333332,
#  'many': 0.25,
#  'observed': 0.22916666666666666,
#  'since': 0.3333333333333333,
#  'mid': 0.14583333333333334,
#  'th': 0.1875,
#  'century': 0.375,
#  'unprecedented': 0.08333333333333333,
#  'decades': 0.14583333333333334,
#  'millennia': 0.08333333333333333,
#  'intergovernmental': 0.0625,
#  'panel': 0.0625,
#  'ipcc': 0.14583333333333334,
#  'fifth': 0.041666666666666664,
#  'assessment': 0.10416666666666667,
#  'report': 0.4791666666666667,
#  'concluded': 0.08333333333333333,
#  'extremely': 0.0625,
#  'likely': 0.16666666666666666,
#  'influence': 0.0625,
#  'dominant': 0.10416666666666667,
#  'cause': 0.125,
#  'largest': 0.041666666666666664,
#  'emission': 0.20833333333333334,
#  'greenhouse': 0.9375,
#  'gases': 0.5833333333333334,
#  'carbon': 0.7291666666666666,
#  'dioxide': 0.25,
#  'methane': 0.14583333333333334,
#  'nitrous': 0.0625,
#  'oxide': 0.0625,
#  'model': 0.10416666666666667,
#  'projections': 0.10416666666666667,
#  'summarized': 0.020833333333333332,
#  'indicated': 0.020833333333333332,
#  'st': 0.10416666666666667,
#  'c': 0.4375,
#  'f': 0.14583333333333334,
#  'moderate': 0.020833333333333332,
#  'scenario': 0.14583333333333334,
#  'much': 0.16666666666666666,
#  'extreme': 0.10416666666666667,
#  'depending': 0.041666666666666664,
#  'rate': 0.20833333333333334,
#  'future': 0.3125,
#  'gas': 0.3541666666666667,
#  'emissions': 1.0,
#  'feedback': 0.4,
#  'findings': 0.03333333333333333,
#  'recognized': 0.03333333333333333,
#  'national': 0.26666666666666666,
#  'science': 0.06666666666666667,
#  'academies': 0.06666666666666667,
#  'industrialized': 0.03333333333333333,
#  'nations': 0.2,
#  'disputed': 0.06666666666666667,
#  'scientific': 0.4666666666666667,
#  'body': 0.06666666666666667,
#  'international': 0.1,
#  'standing': 0.06666666666666667,
#  'include': 0.36666666666666664,
#  'rising': 0.26666666666666666,
#  'sea': 0.5333333333333333,
#  'levels': 0.6,
#  'regional': 0.13333333333333333,
#  'frequent': 0.03333333333333333,
#  'weather': 0.16666666666666666,
#  'events': 0.16666666666666666,
#  'heat': 0.6666666666666666,
#  'waves': 0.16666666666666666,
#  'expansion': 0.1,
#  'deserts': 0.06666666666666667,
#  'increases': 0.3,
#  'greatest': 0.1,
#  'arctic': 0.5333333333333333,
#  'contributed': 0.16666666666666666,
#  'retreat': 0.06666666666666667,
#  'glaciers': 0.13333333333333333,
#  'permafrost': 0.13333333333333333,
#  'ice': 0.7333333333333333,
#  'overall': 0.16666666666666666,
#  'higher': 0.4,
#  'bring': 0.1,
#  'rain': 0.06666666666666667,
#  'snowfall': 0.03333333333333333,
#  'regions': 0.5333333333333333,
#  'droughts': 0.1,
#  'wildfires': 0.03333333333333333,
#  'instead': 0.06666666666666667,
#  'threatens': 0.06666666666666667,
#  'diminish': 0.03333333333333333,
#  'crop': 0.16666666666666666,
#  'yields': 0.03333333333333333,
#  'harming': 0.03333333333333333,
#  'food': 0.16666666666666666,
#  'security': 0.1,
#  'may': 0.5666666666666667,
#  'flood': 0.03333333333333333,
#  'coastal': 0.06666666666666667,
#  'infrastructure': 0.06666666666666667,
#  'force': 0.03333333333333333,
#  'abandonment': 0.03333333333333333,
#  'cities': 0.06666666666666667,
#  'environmental': 0.1,
#  'extinction': 0.13333333333333333,
#  'relocation': 0.03333333333333333,
#  'species': 0.16666666666666666,
#  'ecosystems': 0.2,
#  'immediately': 0.03333333333333333,
#  'environments': 0.03333333333333333,
#  'coral': 0.06666666666666667,
#  'reefs': 0.06666666666666667,
#  'mountains': 0.03333333333333333,
#  'due': 0.5,
#  'persistence': 0.03333333333333333,
#  'co': 1.0,
#  'atmosphere': 0.8333333333333334,
#  'inertia': 0.1,
#  'climatic': 0.2,
#  'continue': 0.2,
#  'even': 0.13333333333333333,
#  'stopped': 0.06666666666666667,
#  'possible': 0.1,
#  'societal': 0.06666666666666667,
#  'responses': 0.1,
#  'mitigation': 0.23333333333333334,
#  'reduction': 0.13333333333333333,
#  'adaptation': 0.43333333333333335,
#  'maybe': 0.03333333333333333,
#  'engineering': 0.1,
#  'countries': 0.7,
#  'work': 0.06666666666666667,
#  'together': 0.06666666666666667,
#  'umbrella': 0.03333333333333333,
#  'united': 0.23333333333333334,
#  'framework': 0.13333333333333333,
#  'convention': 0.23333333333333334,
#  'unfccc': 0.13333333333333333,
#  'near': 0.16666666666666666,
#  'universal': 0.03333333333333333,
#  'membership': 0.03333333333333333,
#  'ultimate': 0.03333333333333333,
#  'goal': 0.03333333333333333,
#  'prevent': 0.06666666666666667,
#  'dangerous': 0.06666666666666667,
#  'anthropogenic': 0.13333333333333333,
#  'interference': 0.06666666666666667,
#  'although': 0.13333333333333333,
#  'parties': 0.16666666666666666,
#  'agreed': 0.06666666666666667,
#  'deep': 0.03333333333333333,
#  'cuts': 0.03333333333333333,
#  'required': 0.03333333333333333,
#  'limited': 0.06666666666666667,
#  'well': 0.3333333333333333,
#  'paris': 0.23333333333333334,
#  'agreement': 0.26666666666666666,
#  'already': 0.16666666666666666,
#  'increased': 1.0,
#  'half': 0.21739130434782608,
#  'threshold': 0.08695652173913043,
#  'pledges': 0.08695652173913043,
#  'cut': 0.08695652173913043,
#  'inadequate': 0.043478260869565216,
#  'limit': 0.21739130434782608,
#  'scientists': 0.4782608695652174,
#  'question': 0.043478260869565216,
#  'feasibility': 0.043478260869565216,
#  'scenarios': 0.391304347826087,
#  'proxy': 0.043478260869565216,
#  'records': 0.08695652173913043,
#  'show': 0.043478260869565216,
#  'natural': 0.34782608695652173,
#  'variations': 0.2608695652173913,
#  'offset': 0.043478260869565216,
#  'early': 0.17391304347826086,
#  'industrial': 0.5652173913043478,
#  'revolution': 0.13043478260869565,
#  'little': 0.13043478260869565,
#  'net': 0.17391304347826086,
#  'thermometer': 0.043478260869565216,
#  'began': 0.13043478260869565,
#  'provide': 0.08695652173913043,
#  'coverage': 0.08695652173913043,
#  'adopted': 0.043478260869565216,
#  'baseline': 0.08695652173913043,
#  'reference': 0.043478260869565216,
#  'period': 0.30434782608695654,
#  'approximation': 0.043478260869565216,
#  'pre': 0.34782608695652173,
#  'mean': 0.13043478260869565,
#  'multiple': 0.043478260869565216,
#  'independently': 0.043478260869565216,
#  'produced': 0.13043478260869565,
#  'instrumental': 0.08695652173913043,
#  'datasets': 0.043478260869565216,
#  'confirm': 0.08695652173913043,
#  'decade': 0.08695652173913043,
#  'warmer': 0.30434782608695654,
#  'currently': 0.043478260869565216,
#  'per': 0.17391304347826086,
#  'number': 0.08695652173913043,
#  'cold': 0.043478260869565216,
#  'days': 0.08695652173913043,
#  'nights': 0.043478260869565216,
#  'decreased': 0.043478260869565216,
#  'warm': 0.08695652173913043,
#  'night': 0.043478260869565216,
#  'historical': 0.08695652173913043,
#  'patterns': 0.13043478260869565,
#  'cooling': 0.391304347826087,
#  'like': 0.13043478260869565,
#  'medieval': 0.043478260869565216,
#  'anomaly': 0.043478260869565216,
#  'age': 0.13043478260869565,
#  'synchronous': 0.043478260869565216,
#  'reached': 0.13043478260869565,
#  'high': 0.43478260869565216,
#  'late': 0.13043478260869565,
#  'set': 0.21739130434782608,
#  'common': 0.13043478260869565,
#  'measure': 0.13043478260869565,
#  'atmospheric': 0.43478260869565216,
#  'additional': 0.21739130434782608,
#  'energy': 0.6086956521739131,
#  'stored': 0.043478260869565216,
#  'last': 0.17391304347826086,
#  'years': 0.6086956521739131,
#  'warmed': 0.30434782608695654,
#  'ocean': 0.782608695652174,
#  'water': 0.6956521739130435,
#  'remainder': 0.043478260869565216,
#  'melted': 0.043478260869565216,
#  'continents': 0.08695652173913043,
#  'evident': 0.043478260869565216,
#  'record': 0.13043478260869565,
#  'consistent': 0.043478260869565216,
#  'wide': 0.13043478260869565,
#  'range': 0.13043478260869565,
#  'observations': 0.08695652173913043,
#  'documented': 0.13043478260869565,
#  'independent': 0.08695652173913043,
#  'groups': 0.08695652173913043,
#  'example': 0.2608695652173913,
#  'continental': 0.043478260869565216,
#  'frequency': 0.08695652173913043,
#  'intensity': 0.043478260869565216,
#  'heavy': 0.043478260869565216,
#  'examples': 0.13043478260869565,
#  'level': 0.5652173913043478,
#  'widespread': 0.08695652173913043,
#  'melting': 0.08695652173913043,
#  'snow': 0.21739130434782608,
#  'land': 1.0,
#  'content': 0.05,
#  'oceans': 0.35,
#  'humidity': 0.1,
#  'earlier': 0.15,
#  'timing': 0.1,
#  'spring': 0.1,
#  'flowering': 0.05,
#  'plants': 0.15,
#  'refers': 0.05,
#  'averages': 0.05,
#  'amount': 0.35,
#  'varying': 0.05,
#  'almost': 0.05,
#  'twice': 0.15,
#  'fast': 0.1,
#  'larger': 0.1,
#  'capacity': 0.25,
#  'lose': 0.05,
#  'evaporation': 0.1,
#  'locations': 0.05,
#  'persist': 0.1,
#  'enough': 0.1,
#  'diffuse': 0.05,
#  'across': 0.2,
#  'planet': 0.25,
#  'localized': 0.05,
#  'black': 0.2,
#  'deposits': 0.1,
#  'contribute': 0.1,
#  'northern': 0.2,
#  'hemisphere': 0.15,
#  'north': 0.25,
#  'pole': 0.1,
#  'faster': 0.1,
#  'south': 0.15,
#  'southern': 0.1,
#  'arrangement': 0.05,
#  'masses': 0.05,
#  'around': 0.15,
#  'resulted': 0.05,
#  'maximum': 0.1,
#  'area': 0.1,
#  'flipping': 0.05,
#  'reflective': 0.1,
#  'cover': 0.25,
#  'surfaces': 0.05,
#  'absorb': 0.25,
#  'sunlight': 0.6,
#  'thus': 0.15,
#  'predicted': 0.1,
#  'rest': 0.1,
#  'world': 0.6,
#  'difference': 0.15,
#  'equator': 0.05,
#  'decreases': 0.1,
#  'currents': 0.05,
#  'driven': 0.05,
#  'gulf': 0.05,
#  'stream': 0.1,
#  'weakening': 0.05,
#  'large': 0.4,
#  'thermal': 0.1,
#  'take': 0.1,
#  'centuries': 0.2,
#  'fully': 0.1,
#  'adjust': 0.05,
#  'breaking': 0.05,
#  'attract': 0.05,
#  'considerable': 0.1,
#  'public': 0.45,
#  'interest': 0.1,
#  'individual': 0.05,
#  'less': 0.45,
#  'significant': 0.15,
#  'trend': 0.2,
#  'subject': 0.2,
#  'short': 0.1,
#  'fluctuations': 0.1,
#  'overlie': 0.05,
#  'trends': 0.1,
#  'temporarily': 0.05,
#  'mask': 0.05,
#  'magnify': 0.05,
#  'episode': 0.05,
#  'slower': 0.1,
#  'dubbed': 0.05,
#  'hiatus': 0.05,
#  'throughout': 0.05,
#  'storage': 0.1,
#  'continued': 0.1,
#  'progress': 0.05,
#  'steadily': 0.05,
#  'upwards': 0.1,
#  'subsequent': 0.1,
#  'spiked': 0.05,
#  'pace': 0.05,
#  'attributed': 0.2,
#  'combination': 0.1,
#  'reduced': 0.25,
#  'solar': 0.45,
#  'activity': 0.35,
#  'volcanic': 0.25,
#  'experiences': 0.05,
#  'cycles': 0.05,
#  'el': 0.05,
#  'niño': 0.05,
#  'oscillation': 0.05,
#  'external': 0.35,
#  'forcings': 0.3,
#  'always': 0.05,
#  'composition': 0.1,
#  'e': 0.15,
#  'g': 0.1,
#  'concentrations': 0.4,
#  'luminosity': 0.05,
#  'eruptions': 0.05,
#  'orbit': 0.1,
#  'sun': 0.45,
#  'attributing': 0.05,
#  'detected': 0.15,
#  'requires': 0.1,
#  'rule': 0.05,
#  'known': 0.2,
#  'internal': 0.05,
#  'variability': 0.1,
#  'therefore': 0.1,
#  'key': 0.1,
#  'approach': 0.1,
#  'use': 0.55,
#  'physically': 0.05,
#  'statistically': 0.05,
#  'based': 0.2,
#  'computer': 0.1,
#  'modelling': 0.1,
#  'determine': 0.05,
#  'unique': 0.05,
#  'fingerprints': 0.1,
#  'potential': 0.25,
#  'causes': 0.5,
#  'comparing': 0.05,
#  'evolution': 0.1,
#  'determined': 0.15,
#  'factors': 0.1,
#  'causing': 0.2,
#  'aerosols': 0.55,
#  'soot': 0.2,
#  'trap': 0.05,
#  'radiating': 0.05,
#  'space': 0.2,
#  'form': 0.05,
#  'infrared': 0.5,
#  'radiation': 0.55,
#  'gets': 0.15,
#  'absorbed': 0.2,
#  'emitted': 0.05,
#  'lower': 0.25,
#  'naturally': 0.1,
#  'occurring': 0.05,
#  'amounts': 0.1,
#  'air': 0.5,
#  'would': 0.85,
#  'absence': 0.05,
#  'without': 0.2,
#  'freezing': 0.05,
#  'vapour': 0.4,
#  'clouds': 0.45,
#  'biggest': 0.05,
#  'contributors': 0.05,
#  'effect': 1.0,
#  'function': 0.05555555555555555,
#  'considered': 0.1111111111111111,
#  'feedbacks': 0.4444444444444444,
#  'ozone': 0.2777777777777778,
#  'n': 0.1111111111111111,
#  'forcing': 0.2777777777777778,
#  'hand': 0.05555555555555555,
#  'leading': 0.2222222222222222,
#  'radiative': 0.16666666666666666,
#  'tropospheric': 0.1111111111111111,
#  'cfcs': 0.05555555555555555,
#  'respectively': 0.05555555555555555,
#  'times': 0.1111111111111111,
#  'readings': 0.05555555555555555,
#  'taken': 0.1111111111111111,
#  'primary': 0.1111111111111111,
#  'benchmark': 0.05555555555555555,
#  'site': 0.05555555555555555,
#  'mauna': 0.05555555555555555,
#  'loa': 0.05555555555555555,
#  'surpassing': 0.05555555555555555,
#  'ppm': 0.1111111111111111,
#  'first': 0.2222222222222222,
#  'time': 0.2777777777777778,
#  'reliable': 0.05555555555555555,
#  'data': 0.16666666666666666,
#  'collected': 0.05555555555555555,
#  'cores': 0.05555555555555555,
#  'geological': 0.1111111111111111,
#  'evidence': 0.2777777777777778,
#  'indicates': 0.05555555555555555,
#  'values': 0.05555555555555555,
#  'millions': 0.05555555555555555,
#  'equivalent': 0.05555555555555555,
#  'billion': 0.05555555555555555,
#  'tonnes': 0.05555555555555555,
#  'using': 0.2777777777777778,
#  'recent': 0.2222222222222222,
#  'potentials': 0.05555555555555555,
#  'ar': 0.5,
#  'fossil': 0.4444444444444444,
#  'fuel': 0.2777777777777778,
#  'burning': 0.2777777777777778,
#  'industry': 0.1111111111111111,
#  'primarily': 0.1111111111111111,
#  'deforestation': 0.16666666666666666,
#  'fluorinated': 0.05555555555555555,
#  'life': 0.1111111111111111,
#  'cycle': 0.2777777777777778,
#  'estimate': 0.05555555555555555,
#  'relating': 0.05555555555555555,
#  'final': 0.05555555555555555,
#  'consumption': 0.1111111111111111,
#  'sources': 0.1111111111111111,
#  'washing': 0.05555555555555555,
#  'heating': 0.16666666666666666,
#  'lighting': 0.05555555555555555,
#  'personal': 0.05555555555555555,
#  'transport': 0.16666666666666666,
#  'freight': 0.05555555555555555,
#  'building': 0.05555555555555555,
#  'construction': 0.05555555555555555,
#  'changing': 0.2777777777777778,
#  'type': 0.1111111111111111,
#  'vegetation': 0.1111111111111111,
#  'local': 0.2222222222222222,
#  'reflected': 0.1111111111111111,
#  'back': 0.1111111111111111,
#  'called': 0.3333333333333333,
#  'albedo': 0.2777777777777778,
#  'lost': 0.05555555555555555,
#  'instance': 0.05555555555555555,
#  'dark': 0.05555555555555555,
#  'forest': 0.05555555555555555,
#  'grassland': 0.05555555555555555,
#  'makes': 0.16666666666666666,
#  'lighter': 0.05555555555555555,
#  'reflect': 0.16666666666666666,
#  'humans': 0.2777777777777778,
#  'create': 0.05555555555555555,
#  'agricultural': 0.1111111111111111,
#  'era': 0.1111111111111111,
#  'processes': 0.2777777777777778,
#  'linked': 0.16666666666666666,
#  'opposite': 0.1111111111111111,
#  'remains': 0.05555555555555555,
#  'unclear': 0.05555555555555555,
#  'solid': 0.05555555555555555,
#  'liquid': 0.05555555555555555,
#  'particles': 0.1111111111111111,
#  'volcanoes': 0.05555555555555555,
#  'plankton': 0.05555555555555555,
#  'made': 0.4444444444444444,
#  'pollutants': 0.05555555555555555,
#  'incoming': 0.16666666666666666,
#  'gradual': 0.1111111111111111,
#  'reaching': 0.3333333333333333,
#  'phenomenon': 0.05555555555555555,
#  'popularly': 0.05555555555555555,
#  'dimming': 0.05555555555555555,
#  'typically': 0.1111111111111111,
#  'biofuel': 0.05555555555555555,
#  'aerosol': 0.05555555555555555,
#  'removal': 0.1111111111111111,
#  'gives': 0.05555555555555555,
#  'lifetime': 0.1111111111111111,
#  'week': 0.05555555555555555,
#  'stratospheric': 0.05555555555555555,
#  'remain': 0.1111111111111111,
#  'globally': 0.05555555555555555,
#  'declining': 0.05555555555555555,
#  'removing': 0.05555555555555555,
#  'masking': 0.05555555555555555,
#  'providing': 0.05555555555555555,
#  'addition': 0.05555555555555555,
#  'scattering': 0.05555555555555555,
#  'absorbing': 0.05555555555555555,
#  'indirect': 0.2222222222222222,
#  'budget': 0.05555555555555555,
#  'sulfate': 0.05555555555555555,
#  'act': 0.05555555555555555,
#  'cloud': 0.3888888888888889,
#  'condensation': 0.05555555555555555,
#  'nuclei': 0.05555555555555555,
#  'lead': 0.3333333333333333,
#  'smaller': 0.05555555555555555,
#  'droplets': 0.16666666666666666,
#  'efficiently': 0.05555555555555555,
#  'fewer': 0.1111111111111111,
#  'also': 0.8333333333333334,
#  'uniform': 0.05555555555555555,
#  'size': 0.05555555555555555,
#  'reduces': 0.2222222222222222,
#  'growth': 0.3333333333333333,
#  'raindrops': 0.05555555555555555,
#  'uncertainty': 0.2777777777777778,
#  'reflecting': 0.05555555555555555,
#  'falls': 0.05555555555555555,
#  'absorption': 0.05555555555555555,
#  'limiting': 0.1111111111111111,
#  'new': 0.16666666666666666,
#  'could': 1.0,
#  'reduce': 0.23529411764705882,
#  'suspended': 0.058823529411764705,
#  'directly': 0.17647058823529413,
#  'absorbs': 0.058823529411764705,
#  'areas': 0.23529411764705882,
#  'production': 0.29411764705882354,
#  'rural': 0.058823529411764705,
#  'india': 0.17647058823529413,
#  'masked': 0.058823529411764705,
#  'brown': 0.058823529411764705,
#  'influences': 0.058823529411764705,
#  'including': 0.47058823529411764,
#  'pronounced': 0.17647058823529413,
#  'tropics': 0.058823529411764705,
#  'latitudes': 0.23529411764705882,
#  'parts': 0.058823529411764705,
#  'source': 0.35294117647058826,
#  'affect': 0.23529411764705882,
#  'irradiance': 0.058823529411764705,
#  'measured': 0.11764705882352941,
#  'satellites': 0.058823529411764705,
#  'available': 0.058823529411764705,
#  'beginning': 0.058823529411764705,
#  'upward': 0.11764705882352941,
#  'responsible': 0.17647058823529413,
#  'physical': 0.4117647058823529,
#  'models': 1.0,
#  'unable': 0.13333333333333333,
#  'reproduce': 0.13333333333333333,
#  'rapid': 0.4666666666666667,
#  'taking': 0.06666666666666667,
#  'account': 0.13333333333333333,
#  'output': 0.13333333333333333,
#  'another': 0.2,
#  'line': 0.06666666666666667,
#  'different': 1.0,
#  'according': 0.18181818181818182,
#  'basic': 0.09090909090909091,
#  'principles': 0.09090909090909091,
#  'produces': 0.18181818181818182,
#  'troposphere': 0.2727272727272727,
#  'upper': 0.09090909090909091,
#  'stratosphere': 0.18181818181818182,
#  'expected': 1.0,
#  'case': 0.1,
#  'lowest': 0.1,
#  'layer': 0.2,
#  'furthermore': 0.2,
#  'highly': 0.1,
#  'reactive': 0.1,
#  'interacts': 0.1,
#  'response': 0.4,
#  'initial': 0.2,
#  'positive': 0.8,
#  'negative': 0.8,
#  'main': 0.4,
#  'strongly': 0.1,
#  'increasing': 0.9,
#  'probably': 0.5,
#  'reason': 0.1,
#  'project': 0.2,
#  'magnitudes': 0.2,
#  'given': 0.2,
#  'hold': 0.2,
#  'moisture': 0.1,
#  'potent': 0.1,
#  'heats': 0.1,
#  'contributing': 0.1,
#  'amplification': 0.2,
#  'released': 0.1,
#  'melts': 0.1,
#  'surpass': 0.1,
#  'second': 0.2,
#  'strongest': 0.1,
#  'end': 0.2,
#  'simultaneously': 0.2,
#  'enhance': 0.1,
#  'true': 0.1,
#  'depends': 0.1,
#  'location': 0.1,
#  'process': 0.3,
#  'important': 0.4,
#  'analysis': 0.1,
#  'satellite': 0.1,
#  'reveals': 0.1,
#  'tops': 0.1,
#  'cloudy': 0.1,
#  'storm': 0.1,
#  'tracks': 0.1,
#  'shifting': 0.1,
#  'toward': 0.1,
#  'poles': 0.2,
#  'suggesting': 0.2,
#  'roughly': 0.1,
#  'year': 0.3,
#  'extended': 0.1,
#  'growing': 0.1,
#  'season': 0.1,
#  'stimulated': 0.1,
#  'plant': 0.4,
#  'making': 0.2,
#  'inhibit': 0.1,
#  'uncertain': 0.2,
#  'whether': 0.5,
#  'soils': 0.1,
#  'contain': 0.1,
#  'quantities': 0.1,
#  'release': 0.2,
#  'acidifying': 0.1,
#  'circulation': 0.4,
#  'concern': 0.5,
#  'tipping': 0.2,
#  'point': 0.2,
#  'transition': 0.1,
#  'hothouse': 0.2,
#  'state': 0.2,
#  'eliminated': 0.1,
#  'study': 0.3,
#  'tried': 0.1,
#  'identify': 0.1,
#  'planetary': 0.1,
#  'self': 0.2,
#  'reinforcing': 0.1,
#  'found': 0.8,
#  'trigger': 0.2,
#  'representation': 0.1,
#  'chemical': 0.1,
#  'biological': 0.1,
#  'run': 0.2,
#  'supercomputers': 0.1,
#  'predict': 0.2,
#  'annual': 0.2,
#  'seasons': 0.1,
#  'flows': 0.1,
#  'two': 0.4,
#  'dozen': 0.1,
#  'institutions': 0.1,
#  'develop': 0.1,
#  'agree': 0.1,
#  'strength': 0.1,
#  'sensitivity': 0.2,
#  'subset': 0.1,
#  'add': 0.1,
#  'simple': 0.2,
#  'simulate': 0.2,
#  'population': 0.6,
#  'economic': 0.7,
#  'interact': 0.1,
#  'information': 0.1,
#  'produce': 0.1,
#  'vary': 0.2,
#  'generate': 0.1,
#  'inputs': 0.1,
#  'four': 0.2,
#  'rcps': 0.2,
#  'representative': 0.1,
#  'concentration': 0.3,
#  'pathways': 0.1,
#  'stringent': 0.2,
#  'rcp': 0.4,
#  'intermediate': 0.1,
#  'one': 0.4,
#  'ghg': 0.1,
#  'look': 0.1,
#  'factoring': 0.1,
#  'remove': 0.1,
#  'realism': 0.1,
#  'tested': 0.1,
#  'examining': 0.1,
#  'ability': 0.2,
#  'contemporary': 0.1,
#  'past': 0.3,
#  'climates': 0.1,
#  'underestimated': 0.3,
#  'shrinkage': 0.1,
#  'older': 0.1,
#  'agrees': 0.1,
#  'states': 0.3,
#  'published': 0.5,
#  'notes': 0.1,
#  'still': 0.2,
#  'underestimating': 0.1,
#  'missing': 0.1,
#  'relevant': 0.1,
#  'broad': 0.1,
#  'far': 0.2,
#  'occur': 0.4,
#  'gradually': 0.1,
#  'rapidly': 0.2,
#  'rose': 0.1,
#  'mm': 0.1,
#  'acceleration': 0.1,
#  'projects': 0.1,
#  'cm': 0.1,
#  'loss': 0.2,
#  'sheets': 0.1,
#  'antarctic': 0.2,
#  'warmth': 0.4,
#  'undermining': 0.1,
#  'threatening': 0.1,
#  'unplug': 0.1,
#  'glacier': 0.2,
#  'outlets': 0.1,
#  'potentially': 0.3,
#  'resulting': 0.1,
#  'non': 0.1,
#  'polar': 0.1,
#  'contributes': 0.1,
#  'led': 0.2,
#  'shrinking': 0.1,
#  'thinning': 0.1,
#  'vulnerable': 0.2,
#  'anomalies': 0.1,
#  'declines': 0.1,
#  'free': 0.2,
#  'summers': 0.1,
#  'rare': 0.1,
#  'degrees': 0.1,
#  'every': 0.3,
#  'three': 0.4,
#  'ten': 0.1,
#  'dissolved': 0.1,
#  'acidification': 0.2,
#  'oxygen': 0.3,
#  'decrease': 0.1,
#  'soluble': 0.1,
#  'deoxygenation': 0.1,
#  'seen': 0.1,
#  'spells': 0.1,
#  'virtually': 0.1,
#  'certain': 0.3,
#  'appeared': 0.4,
#  'wet': 0.1,
#  'dry': 0.4,
#  'within': 0.4,
#  'monsoon': 0.1,
#  'east': 0.2,
#  'asia': 0.4,
#  'mechanisms': 0.1,
#  'identified': 0.1,
#  'might': 0.5,
#  'explain': 0.2,
#  'jet': 0.1,
#  'becoming': 0.2,
#  'erratic': 0.1,
#  'rainfall': 0.1,
#  'wind': 0.1,
#  'speed': 0.1,
#  'hurricanes': 0.1,
#  'typhoons': 0.1,
#  'timescale': 0.1,
#  'magnitude': 0.1,
#  'estimated': 0.2,
#  'prolonged': 0.1,
#  'interglacial': 0.1,
#  'least': 0.3,
#  'great': 0.1,
#  'mass': 0.2,
#  'caps': 0.1,
#  'depressed': 0.1,
#  'crust': 0.1,
#  'melt': 0.1,
#  'deglaciation': 0.1,
#  'landmasses': 0.1,
#  'post': 0.1,
#  'glacial': 0.1,
#  'rebound': 0.1,
#  'facilitating': 0.1,
#  'seismic': 0.1,
#  'places': 0.2,
#  'iceland': 0.1,
#  'tsunamis': 0.1,
#  'generated': 0.1,
#  'submarine': 0.1,
#  'landslides': 0.1,
#  'thawing': 0.1,
#  'floor': 0.1,
#  'releasing': 0.1,
#  'hydrates': 0.1,
#  'abrupt': 0.2,
#  'points': 0.1,
#  'result': 0.3,
#  'scale': 0.5,
#  'abruptly': 0.1,
#  'irreversible': 0.2,
#  'amplify': 0.1,
#  'possibility': 0.1,
#  'atlantic': 0.2,
#  'meridional': 0.1,
#  'overturning': 0.1,
#  'slow': 0.1,
#  'shut': 0.1,
#  'see': 0.1,
#  'shutdown': 0.1,
#  'thermohaline': 0.1,
#  'europe': 0.2,
#  'america': 0.6,
#  'terrestrial': 0.1,
#  'poleward': 0.1,
#  'shifts': 0.3,
#  'animal': 0.1,
#  'ranges': 0.1,
#  'confidence': 0.2,
#  'affected': 0.3,
#  'drier': 0.1,
#  'zones': 0.2,
#  'subtropics': 0.1,
#  'substantial': 0.2,
#  'actions': 0.2,
#  'risk': 0.6,
#  'structure': 0.1,
#  'diversity': 0.1,
#  'push': 0.2,
#  'bees': 0.1,
#  'physiological': 0.1,
#  'limits': 0.1,
#  'bee': 0.1,
#  'populations': 0.3,
#  'heated': 0.2,
#  'slowly': 0.1,
#  'animals': 0.2,
#  'migrated': 0.1,
#  'towards': 0.1,
#  'colder': 0.1,
#  'harmful': 0.1,
#  'organisms': 0.1,
#  'corals': 0.1,
#  'kelp': 0.1,
#  'seabirds': 0.1,
#  'damage': 0.1,
#  'fisheries': 0.1,
#  'protected': 0.1,
#  'resources': 0.1,
#  'value': 0.1,
#  'society': 0.3,
#  'oceanic': 0.1,
#  'brain': 0.1,
#  'central': 0.1,
#  'nervous': 0.1,
#  'fish': 0.1,
#  'hear': 0.1,
#  'smell': 0.1,
#  'evade': 0.1,
#  'predators': 0.1,
#  'systems': 0.2,
#  'mostly': 0.1,
#  'worldwide': 0.5,
#  'social': 0.2,
#  'uneven': 0.1,
#  'experiencing': 0.1,
#  'low': 0.8,
#  'latitude': 0.3,
#  'developed': 0.5,
#  'facing': 0.1,
#  'inequality': 0.1,
#  'observable': 0.1,
#  'africa': 0.3,
#  'small': 0.3,
#  'islands': 0.3,
#  'asian': 0.1,
#  'megadeltas': 0.1,
#  'especially': 0.4,
#  'risks': 0.2,
#  'negatively': 0.1,
#  'relative': 0.3,
#  'pose': 0.1,
#  'impact': 0.3,
#  'productivity': 0.1,
#  'crops': 0.3,
#  'wheat': 0.1,
#  'maize': 0.1,
#  'neutral': 0.1,
#  'soy': 0.1,
#  'rice': 0.1,
#  'million': 0.3,
#  'people': 1.0,
#  'particularly': 0.3333333333333333,
#  'incomes': 0.1111111111111111,
#  'hunger': 0.1111111111111111,
#  'consequence': 0.2222222222222222,
#  'help': 0.2222222222222222,
#  'become': 0.2222222222222222,
#  'nutritious': 0.1111111111111111,
#  'indigenous': 0.1111111111111111,
#  'knowledge': 0.1111111111111111,
#  'affecting': 0.2222222222222222,
#  'mountain': 0.1111111111111111,
#  'drylands': 0.1111111111111111,
#  'dependent': 0.1111111111111111,
#  'stress': 0.1111111111111111,
#  'generally': 0.3333333333333333,
#  'health': 0.1111111111111111,
#  'injury': 0.1111111111111111,
#  ...}

# %%
# calculate sentences score
sent2score ={}

for sentence in sentences:
    for word in nltk.word_tokenize(sentence.lower()):
        if word in word2score.keys():
            if len(sentence.split(' ')) < 30:
                if sentence not in sent2score.keys():
                    sent2score[sentence] = word2score[word]
                else:
                    sent2score[sentence] += word2score[word]

# %%
sent2score
# Out:
# {" Global warming is the long-term rise in the average temperature of the Earth's climate system.": 3.2644366197183103,
#  'It is a major aspect of current climate change, and has been demonstrated by direct temperature measurements and by measurements of various effects of the warming.': 4.2426056338028175,
#  'The terms global warming and climate change are often used interchangeably.': 3.691666666666667,
#  'There have been prehistoric periods of global warming, but many observed changes since the mid-20th century have been unprecedented over decades to millennia.': 3.462500000000001,
#  'The largest human influence has been the emission of greenhouse gases such as carbon dioxide, methane, and nitrous oxide.': 3.4375,
#  'These findings have been recognized by the national science academies of the major industrialized nations and are not disputed by any scientific body of national or international standing.': 1.8460093896713614,
#  'The effects of global warming include rising sea levels, regional changes in precipitation, more frequent extreme weather events such as heat waves, and expansion of deserts.': 5.937500000000001,
#  'Surface temperature increases are greatest in the Arctic, which has contributed to the retreat of glaciers, permafrost, and sea ice.': 3.45,
#  'Overall, higher temperatures bring more rain and snowfall, but for some regions droughts and wildfires increase instead.': 2.3541666666666674,
#  'Climate change threatens to diminish crop yields, harming food security, and rising sea levels may flood coastal infrastructure and force the abandonment of many coastal cities.': 5.183333333333332,
#  'Environmental impacts include the extinction or relocation of many species as their ecosystems change, most immediately the environments of coral reefs, mountains, and the Arctic.': 3.2041666666666666,
#  'Possible societal responses to global warming include mitigation by emissions reduction, adaptation to its effects, and maybe climate engineering.': 5.529166666666666,
#  'Countries work together on climate change under the umbrella of the United Nations Framework Convention on Climate Change (UNFCCC), which has near-universal membership.': 5.833333333333333,
#  'The ultimate goal of the convention is to "prevent dangerous anthropogenic interference with the climate system".': 1.872769953051643,
#  'Some scientists question the feasibility, in higher emissions scenarios, of climate adaptation.': 3.7898550724637685,
#  'The IPCC has adopted the baseline reference period 1850–1900 as an approximation of pre-industrial global mean surface temperature.': 2.2230072463768114,
#  'Multiple independently produced instrumental datasets confirm that the 2009–2018 decade was 0.93 ± 0.07 °C warmer than the pre-industrial baseline (1850–1900).': 0.9130434782608696,
#  'Currently, surface temperatures are rising by about 0.2 °C per decade.': 1.5085144927536231,
#  'Since 1950, the number of cold days and nights have decreased, and the number of warm days and night have increased.': 1.9420289855072461,
#  'The remainder of the additional energy has melted ice and warmed the continents and the atmosphere.': 2.8710144927536234,
#  'Global warming refers to global averages, with the amount of warming varying by region.': 3.4458333333333333,
#  'Since the pre-industrial period, global average land temperatures have increased almost twice as fast as global average temperatures.': 5.279347826086957,
#  'This is due to the larger heat capacity of oceans and because oceans lose more heat by evaporation.': 3.033333333333333,
#  'The Northern Hemisphere and North Pole have warmed much faster than the South Pole and Southern Hemisphere.': 1.7710144927536233,
#  'Arctic temperatures have increased and are predicted to continue to increase during this century at over twice the rate of the rest of the world.': 4.120833333333334,
#  'As the temperature difference between the Arctic and the equator decreases, ocean currents that are driven by that temperature difference, like the Gulf Stream, are weakening.': 2.696376811594203,
#  'Because the climate system has large thermal inertia, it can take centuries for the climate to fully adjust.': 3.2894366197183103,
#  'While record-breaking years attract considerable public interest, individual years are less significant than the overall trend.': 2.934057971014493,
#  'Global surface temperature is subject to short-term fluctuations that overlie long-term trends, and can temporarily mask or magnify them.': 2.0250000000000004,
#  'An example of such an episode is the slower rate of surface temperature increase from 1998 to 2012, which was dubbed the global warming hiatus.': 3.327536231884058,
#  'Throughout this period ocean heat storage continued to progress steadily upwards, and in subsequent years surface temperatures have spiked upwards.': 3.99981884057971,
#  'The slower pace of warming can be attributed to a combination of natural fluctuations, reduced solar activity, and increased volcanic activity.': 4.314492753623188,
#  'By itself, the climate system experiences various cycles which can last for years (such as the El Niño–Southern Oscillation) to decades or centuries.': 2.692878648703817,
#  'Other changes are caused by external forcings.': 1.3583333333333334,
#  'These forcings are "external" to the climate system, but not always external to the Earth.': 2.447769953051643,
#  'Examples of external forcings include changes in the composition of the atmosphere (e.g.': 2.5596014492753625,
#  "increased concentrations of greenhouse gases), solar luminosity, volcanic eruptions, and variations in the Earth's orbit around the Sun.": 4.840036231884058,
#  'Attributing detected temperature changes and extreme events to human-caused increases in greenhouse gases requires scientists to rule out known internal climate variability and natural external forcings.': 5.996920289855072,
#  'Therefore, a key approach is to use physically or statistically based computer modelling of the climate system to determine unique fingerprints for all potential causes.': 3.5394366197183103,
#  'By comparing these fingerprints with observed patterns and evolution of climate change, and the observed evolution of the forcings, the causes of the observed changes can be determined.': 4.597101449275362,
#  'Scientists have determined that the major factors causing the current climate change are greenhouse gases, land use changes, and aerosols and soot.': 7.481781996325781,
#  'Greenhouse gases trap heat radiating from the Earth to space.': 2.6458333333333335,
#  'This heat, in the form of infrared radiation, gets absorbed and emitted by these gases in the atmosphere, thus warming the lower atmosphere and the surface.': 6.083333333333333,
#  "Without the Earth's atmosphere, the Earth's average temperature would be well below the freezing temperature of water.": 3.83731884057971,
#  'While water vapour (~50%) and clouds (~25%) are the biggest contributors to the greenhouse effect, they increase as a function of temperature and are therefore considered feedbacks.': 4.9609299516908205,
#  'Increased concentrations of gases such as CO2 (~20%), ozone and N2O are external forcing on the other hand.': 2.944444444444444,
#  'As of 2011, the concentrations of CO2 and methane had increased by about 40% and 150%, respectively, since pre-industrial times.': 2.0458333333333334,
#  "In 2013, CO2 readings taken at the world's primary benchmark site in Mauna Loa surpassing 400 ppm for the first time.": 1.7666666666666666,
#  'These levels are much higher than at any time during the last 800,000 years, the period for which reliable data have been collected from ice cores.': 3.5980676328502406,
#  'Less direct geological evidence indicates that CO2 values have not been this high for millions of years.': 2.132367149758454,
#  'For instance, the change from a dark forest to grassland makes the surface lighter, causing it to reflect more sunlight.': 2.9111111111111114,
#  'Humans change the land surface mainly to create more agricultural land.': 4.006944444444445,
#  'Since the pre-industrial era, albedo has increased due to land use change, which has a cooling effect on the planet.': 6.413526570048309,
#  'Other processes linked to land use change however have had the opposite effect, so that the net effect remains unclear.': 5.473913043478261,
#  'Solid and liquid particles known as aerosols – from volcanoes, plankton, and human-made pollutants – reflect incoming sunlight, cooling the climate.': 3.4635265700483093,
#  'Aerosol removal by precipitation gives tropospheric aerosols an atmospheric lifetime of only about a week, while stratospheric aerosols can remain in the atmosphere for a few years.': 3.7684782608695655,
#  'Globally, aerosols have been declining since 1990, removing some of the masking of global warming that they had been providing.': 2.602777777777778,
#  "In addition to their direct effect by scattering and absorbing solar radiation, aerosols have indirect effects on the Earth's radiation budget.": 4.3069444444444445,
#  'Sulfate aerosols act as cloud condensation nuclei and thus lead to clouds that have more and smaller cloud droplets.': 2.7055555555555553,
#  'These clouds reflect solar radiation more efficiently than clouds with fewer and larger droplets.': 2.5,
#  'This effect also causes droplets to be of more uniform size, which reduces the growth of raindrops and makes clouds more reflective to incoming sunlight.': 4.705555555555555,
#  'Indirect effects of aerosols are the largest uncertainty in radiative forcing.': 2.056944444444445,
#  'While aerosols typically limit global warming by reflecting sunlight, black carbon in soot that falls on snow or ice can contribute to global warming.': 6.652838164251207,
#  'Not only does this increase the absorption of sunlight, it also increases melting and sea level rise.': 3.5077294685990332,
#  'Limiting new black carbon deposits in the Arctic could reduce global warming by 0.2 °C by 2050.': 4.517238562091503,
#  'When soot is suspended in the atmosphere, it directly absorbs solar radiation, heating the atmosphere and cooling the surface.': 4.2187553282182435,
#  'In areas with high soot production, such as rural India, as much as 50% of surface warming due to greenhouse gases may be masked by atmospheric brown clouds.': 6.422751491901108,
#  "As the Sun is the Earth's primary energy source, changes in incoming sunlight directly affect the climate system.": 4.578115932022942,
#  'Solar irradiance has been measured directly by satellites, and indirect measurements are available beginning in the early 1600s.': 1.4797136970730325,
#  "There has been no upward trend in the amount of the Sun's energy reaching the Earth, so it cannot be responsible for the current warming.": 3.301991702988605,
#  'Physical climate models are also unable to reproduce the rapid warming observed in recent decades when taking into account only variations in solar output and volcanic activity.': 6.986523159988634,
#  "Another line of evidence for the warming not being due to the Sun is how temperature changes differ at different levels in the Earth's atmosphere.": 5.623611111111111,
#  'According to basic physical principles, the greenhouse effect produces warming of the lower atmosphere (the troposphere), but cooling of the upper atmosphere (the stratosphere).': 6.514811477950863,
#  'If solar variations were responsible for the observed warming, warming of both the troposphere and the stratosphere would be expected, but that has not been the case.': 5.054385607998139,
#  'Ozone in the lowest layer of the atmosphere, the troposphere, is itself a greenhouse gas.': 2.9755050505050504,
#  'Furthermore, it is highly reactive and interacts with other greenhouse gases and aerosols.': 2.5708333333333337,
#  'The response of the climate system to an initial forcing is increased by positive feedbacks and reduced by negative feedbacks.': 5.856103286384976,
#  'The main negative feedback to global temperature change is radiative cooling to space as infrared radiation, which increases strongly with increasing temperature.': 6.882971014492754,
#  'The main positive feedbacks are the water vapour feedback, the ice–albedo feedback, and probably the net effect of clouds.': 5.664009661835749,
#  'Uncertainty over feedbacks is the major reason why different climate models project different magnitudes of warming for a given amount of emissions.': 7.651564945226917,
#  'As air gets warmer, it can hold more moisture.': 1.2543478260869567,
#  'After an initial warming due to emissions of greenhouse gases, the atmosphere will hold more water.': 5.716485507246377,
#  'As water is a potent greenhouse gas, this further heats the climate: the water vapour feedback.': 4.682971014492754,
#  "The reduction of snow cover and sea ice in the Arctic reduces the albedo of the Earth's surface.": 3.5590579710144925,
#  'Cloud cover may change in the future.': 2.5180555555555557,
#  'If cloud cover increases, more sunlight will be reflected back into space, cooling the planet.': 2.602415458937198,
#  'Simultaneously, the clouds enhance the greenhouse effect, warming the planet.': 3.7041666666666666,
#  'The opposite is true if cloud cover decreases.': 0.95,
#  'It depends on the cloud type and location which process is more important.': 1.4,
#  'Overall, the net feedback over the industrial era has probably been positive.': 2.7169082125603863,
#  "Roughly half of each year's CO2 emissions have been absorbed by plants on land and in oceans.": 3.3173913043478263,
#  'Carbon dioxide and an extended growing season have stimulated plant growth making the land carbon cycle a negative feedback.': 5.519444444444445,
#  'Climate change also increases droughts and heat waves that inhibit plant growth, which makes it uncertain whether this negative feedback will persist in the future.': 7.379166666666666,
#  'Soils contain large quantities of carbon and may release some when they heat up.': 2.8625,
#  'As more CO2 and heat are absorbed by the ocean, it is acidifying and ocean circulation can change, changing the rate at which the ocean can absorb atmospheric carbon.': 6.614553140096619,
#  'A climate model is a representation of the physical, chemical, and biological processes that affect the climate system.': 3.5684398876921666,
#  'There are more than two dozen scientific institutions that develop climate models.': 3.166666666666667,
#  'A subset of climate models add societal factors to a simple physical climate model.': 4.082598039215687,
#  'These models simulate how population, economic growth, and energy use affect – and interact with – the physical climate.': 5.739087809036659,
#  'With this information, scientists can produce scenarios of how greenhouse gas emissions may vary in the future.': 4.4403985507246375,
#  'Scientists can then run these scenarios through physical climate models to generate climate change projections.': 5.685496589940324,
#  'Climate models include different external forcings for their models.': 5.016666666666667,
#  "Models also include changes in the Earth's orbit, historical changes in the Sun's activity, and volcanic forcing.": 4.831400966183574,
#  'The physical realism of models is tested by examining their ability to simulate contemporary or past climates.': 2.611764705882353,
#  'Past models have underestimated the rate of Arctic shrinkage and underestimated the rate of precipitation increase.': 3.4916666666666667,
#  'Sea level rise since 1990 was underestimated in older models, but now agrees well with observations.': 3.4688405797101454,
#  'The 2017 United States-published National Climate Assessment notes that "climate models may still be underestimating or missing relevant feedback processes".': 5.44861111111111,
#  'The environmental effects of global warming are broad and far-reaching.': 2.1625,
#  'They include effects on the oceans, ice, and weather and may occur gradually or rapidly.': 3.404166666666667,
#  'Between 1993 and 2017, the global mean sea level rose on average by 3.1 ± 0.3 mm per year, with an acceleration detected as well.': 3.2195652173913043,
#  'Over the 21st century, the IPCC projects that in a high emissions scenario the sea level could rise by 61–110 cm.': 4.516666666666666,
#  'Increased ocean warmth is undermining and threatening to unplug Antarctic glacier outlets, potentially resulting in more rapid sea level rise.': 5.064492753623188,
#  'The retreat of non-polar glaciers also contributes to sea level rise.': 2.3485507246376813,
#  'Global warming has led to decades of shrinking and thinning of the Arctic sea ice, making it vulnerable to atmospheric anomalies.': 4.722282608695652,
#  'Projections of declines in Arctic sea ice vary.': 2.204166666666667,
#  'Higher atmospheric CO2 concentrations have led to an increase in dissolved CO2, which causes ocean acidification.': 3.434057971014493,
#  'Furthermore, oxygen levels decrease because oxygen is less soluble in warmer water, an effect known as ocean deoxygenation.': 5.132608695652174,
#  'Many regions have probably already seen increases in warm spells and heat waves, and it is virtually certain that these changes will continue over the 21st century.': 4.32445652173913,
#  'Since the 1950s, droughts and heat waves have appeared simultaneously with increasing frequency.': 2.8536231884057974,
#  'Extremely wet or dry events within the monsoon period have increased in India and East Asia.': 3.309985080988917,
#  'Various mechanisms have been identified that might explain extreme weather in mid-latitudes from the rapidly warming Arctic, such as the jet stream becoming more erratic.': 3.295833333333334,
#  'The maximum rainfall and wind speed from hurricanes and typhoons are likely increasing.': 1.6666666666666665,
#  'Long-term effects of global warming: On the timescale of centuries to millennia, the magnitude of global warming will be determined primarily by anthropogenic CO2 emissions.': 5.281944444444445,
#  "This is due to carbon dioxide's very long lifetime in the atmosphere.": 2.4902777777777776,
#  'The emissions are estimated to have prolonged the current interglacial period by at least 100,000 years.': 2.753888548683405,
#  'This could be facilitating seismic and volcanic activity in places like Iceland.': 2.2304347826086963,
#  'Tsunamis could be generated by submarine landslides caused by warmer ocean water thawing ocean-floor permafrost or releasing gas hydrates.': 4.199275362318841,
#  'Sea level rise will continue over many centuries.': 1.8652173913043477,
#  'Abrupt climate change, tipping points in the climate system: Climate change could result in global, large-scale changes.': 8.193603286384976,
#  'Some large-scale changes could occur abruptly, i.e.': 1.979166666666667,
#  'over a short time period, and might also be irreversible.': 2.215458937198068,
#  'One potential source of abrupt climate change would be the rapid release of methane and carbon dioxide from permafrost, which would amplify global warming.': 8.369607843137254,
#  'Another example is the possibility for the Atlantic Meridional Overturning Circulation to slow or shut down (see also shutdown of thermohaline circulation).': 3.094202898550725,
#  'This could trigger cooling in the North Atlantic, Europe, and North America.': 3.091304347826087,
#  'It is expected that most ecosystems will be affected by higher atmospheric CO2 levels and higher global temperatures.': 4.4472826086956525,
#  'Global warming has contributed to the expansion of drier climatic zones, such as, probably, the expansion of deserts in the subtropics.': 2.975000000000001,
#  'Without substantial actions to reduce the rate of global warming, land-based ecosystems risk major shifts in their composition and structure.': 3.897970173985087,
#  'Overall, it is expected that climate change will result in the extinction of many species and reduced diversity of ecosystems.': 4.566666666666666,
#  'Rising temperatures push bees to their physiological limits, and could cause the extinction of bee populations.': 2.8625,
#  'Ocean acidification threatens damage to coral reefs, fisheries, protected species, and other natural resources of value to society.': 2.4971014492753625,
#  'Higher oceanic CO2 may affect the brain and central nervous system of certain fish species, which reduces their ability to hear, smell, and evade predators.': 3.230286292920925,
#  'The effects of climate change on human systems, mostly due to warming and shifts in precipitation, have been detected worldwide.': 5.5166666666666675,
#  'The future social impacts of climate change will be uneven across the world.': 3.6000000000000005,
#  'All regions are at risk of experiencing negative impacts, with low-latitude, less developed areas facing the greatest risk.': 4.206127450980392,
#  'Global warming has likely already increased global economic inequality, and is projected to do so in the future.': 4.604166666666667,
#  'Regional impacts of climate change are now observable on all continents and across ocean regions.': 4.023731884057971,
#  'The Arctic, Africa, small islands, and Asian megadeltas are regions that are likely to be especially affected by future climate change.': 5.345833333333333,
#  'Many risks increase with higher magnitudes of global warming.': 2.908333333333333,
#  'Crop production will probably be negatively affected in low-latitude countries, while effects at northern latitudes may be positive or negative.': 5.183578431372549,
#  'Global warming of around 4 °C relative to late 20th century levels could pose a large risk to global and regional food security.': 6.172101449275362,
#  'The impact of climate change on crop productivity for the four major crops was negative for wheat and maize, and neutral for soy and rice, in the years 1960–2013.': 5.088038375178606,
#  'Up to an additional 182 million people worldwide, particularly those with lower incomes, are at risk of hunger as a consequence of warming.': 4.411835748792271,
#  'While increased CO2 levels help crop growth at lower temperature increases, those crops do become less nutritious.': 4.205555555555555,
#  'Based on local and indigenous knowledge, climate change is already affecting food security in mountain regions in South America and Asia, and in various drylands, particularly in Africa.': 5.963888888888888,
#  'Regions dependent on glacier water, regions that are already dry, and small islands are also at increased risk of water stress due to climate change.': 8.980193236714975,
#  'Generally, impacts on public health will be more negative than positive.': 2.6819444444444445,
#  'Impacts include the direct effects of extreme weather, leading to injury and loss of life; and indirect effects, such as undernutrition brought on by crop failures.': 3.316666666666667,
#  'Temperature rise has been connected to increased numbers of suicides.': 1.7000000000000002,
#  'Climate change has been linked to an increase in violent conflict by amplifying poverty and economic shocks, which are well-documented drivers of these conflicts.': 4.95,
#  'Links have been made between a wide range of violent behaviour including fist fights, violent crimes, civil unrest, and wars.': 2.8425689116226205,
#  'Climate change may also lead to new human diseases.': 4.365277777777777,
#  'In small islands and mega deltas, inundation from sea level rise is expected to threaten vital infrastructure and human settlements.': 3.902717391304348,
#  'This could lead to homelessness in countries with low-lying areas such as Bangladesh, as well as statelessness for populations in island nations, such as the Maldives and Tuvalu.': 3.7686274509803925,
#  'Climate change can be an important driver of migration, both within and between countries.': 3.7222222222222223,
#  'The majority of severe impacts of climate change are expected in sub-Saharan Africa and South-East Asia, where existing poverty is exacerbated.': 5.1097222222222225,
#  'Existing stresses include poverty, political conflicts, and ecosystem degradation.': 1.7000000000000002,
#  'Regions may even become uninhabitable, with humidity and temperatures reaching levels too high for humans to survive.': 3.8611714975845417,
#  'Mitigation of and adaptation to climate change are two complementary responses to global warming.': 4.719444444444445,
#  'Successful adaptation is easier if there are substantial emission reductions.': 1.7305555555555556,
#  'Climate change can be mitigated through the reduction of greenhouse gas emissions or the enhancement of the capacity of carbon sinks to absorb greenhouse gases from the atmosphere.': 8.563888888888888,
#  'A 2015 report by Citibank concluded that transitioning to a low-carbon economy would yield a positive return on investments.': 3.1013888888888888,
#  'Over the last three decades of the twentieth century, gross domestic product per capita and population growth were the main drivers of increases in greenhouse gas emissions.': 6.082548309178745,
#  'CO2 emissions are continuing to rise due to the burning of fossil fuels and land-use change.': 3.7833333333333337,
#  'Emissions can be attributed to different regions.': 2.7333333333333334,
#  'The attribution of emissions from land-use change is subject to considerable uncertainty.': 2.688888888888889,
#  'Emissions scenarios, estimates of changes in future emission levels of greenhouse gases, depend upon uncertain economic, sociological, technological, and natural developments.': 6.537741545893717,
#  'In some scenarios emissions continue to rise over the century, while others have reduced emissions.': 3.666304347826087,
#  'Fossil fuel reserves are abundant, and will not limit carbon emissions in the 21st century.': 3.2660024154589373,
#  'Emission scenarios can be combined with modelling of the carbon cycle to predict how atmospheric concentrations of greenhouse gases might change in the future.': 6.408031400966183,
#  'Near- and long-term trends in the global energy system are inconsistent with limiting global warming to below 1.5 or 2 °C relative to pre-industrial levels.': 4.187021160781112,
#  'Current pledges made as part of the Paris Agreement would lead to about 3.0 °C of warming at the end of the 21st century, relative to pre-industrial levels.': 4.708357147717221,
#  'To keep warming below 2 °C, more stringent emission reductions in the near-term would allow for less rapid reductions after 2030, and be cheaper overall.': 4.997222222222223,
#  '[failed verification] To keep warming under 1.5 °C, a far-reaching system change on an unprecedented scale is necessary in energy, land, cities, transport, buildings, and industry.': 5.431465605225556,
#  'Co-benefits of climate change mitigation may help society and individuals more quickly.': 3.5444444444444443,
#  'For example, bicycling reduces greenhouse gas emissions while reducing the effects of a sedentary lifestyle at the same time.': 4.2400362318840585,
#  'The development and scaling-up of clean technology, such as cement that produces less CO2, is critical to achieve sufficient emission reductions for the Paris agreement goals.': 3.562373737373737,
#  'Many integrated models are unable to meet the 2 °C target if pessimistic assumptions are made about the availability of mitigation technologies.': 3.0611111111111113,
#  'It has been suggested that the most effective and comprehensive policy to reduce carbon emissions is a carbon tax or the closely related emissions trading.': 5.138071895424836,
#  'There are diverse opinions on how people could reduce their carbon footprint.': 3.297794117647059,
#  'One suggestion is that the best approach is having fewer children, living car-free, forgoing air travel, and adopting a plant-based diet.': 2.2222222222222223,
#  'Climate change adaptation is "the adjustment in natural or human systems in response to actual or expected climatic stimuli or their effects, which moderates harm or exploits beneficial opportunities."': 6.567270531400964,
#  'Examples of adaptation are improved coastline protection, better disaster management, and the development of more resistant crops.': 2.3082125603864734,
#  'The adaptation may be planned, either in reaction to or anticipation of global warming, or spontaneous, i.e.': 3.2194444444444446,
#  'without government intervention.': 0.9777777777777776,
#  'The public sector, private sector, and communities are all gaining experience with adaptation, and adaptation is becoming embedded within certain planning processes.': 3.6055555555555556,
#  'While some adaptation responses call for trade-offs, others bring synergies and co-benefits.': 1.1888888888888889,
#  'Environmental organizations and public figures have emphasized changes in the climate and the risks they entail, while promoting adaptation to changes in infrastructural needs and emissions reductions.': 5.8083333333333345,
#  'Adaptation is especially important in developing countries since they are predicted to bear the brunt of the effects of global warming.': 5.3291666666666675,
#  'The capacity and potential for humans to adapt, called adaptive capacity, is unevenly distributed across different regions and populations, and developing countries generally have less capacity to adapt.': 7.127777777777778,
#  'Climate engineering (sometimes called geoengineering or climate intervention) is the deliberate modification of the climate.': 4.322222222222223,
#  'It has been investigated as a possible response to global warming by groups including NASA and the Royal Society.': 3.35476697925547,
#  'Techniques studied fall generally into the categories of solar radiation management and carbon dioxide removal, although various other schemes have been suggested.': 3.7930555555555556,
#  'As of 2019[update] nearly all countries in the world are parties to the United Nations Framework Convention on Climate Change (UNFCCC).': 5.177777777777778,
#  'The objective of the Convention is to prevent dangerous human interference with the climate system.': 2.138047730829421,
#  'The Framework Convention was agreed on in 1992, but global emissions have risen since then.': 2.552777777777778,
#  'Its yearly conferences are the stage of global negotiations.': 1.2305555555555556,
#  'This mandate was sustained in the 2005 Kyoto Protocol to the Framework Convention.': 1.838888888888889,
#  'In ratifying the Kyoto Protocol, most developed countries accepted legally binding commitments to limit their emissions.': 4.542391304347826,
#  'These first-round commitments expired in 2012.': 0.375,
#  'In 2009 several UNFCCC Parties produced the Copenhagen Accord, which has been widely portrayed as disappointing because of its low goals, leading poor nations to reject it.': 3.8609903381642514,
#  'Parties associated with the Accord aim to limit the future increase in global mean temperature to below 2 °C.': 2.6686594202898553,
#  'In 2015 all UN countries negotiated the Paris Agreement, which aims to keep climate change well below 2 °C.': 4.241666666666666,
#  'The agreement replaced the Kyoto Protocol.': 1.3916666666666666,
#  'Unlike Kyoto, no binding emission targets are set in the Paris Agreement.': 2.0507246376811596,
#  'Instead, the procedure of regularly setting ever more ambitious goals and reevaluating these goals every five years has been made binding.': 3.5586956521739133,
#  'The Paris Agreement reiterated that developing countries must be financially supported.': 2.477777777777778,
#  'As of September 2019[update] there were 197 Parties to the treaty, of which 165 are Signatories.': 1.3472222222222223,
#  'In 2019, the British Parliament became the first national government in the world to officially declare a climate emergency.': 3.908333333333333,
#  'As at September 2019, nine countries including the United Kingdom, France and Argentina have made national declarations of a climate emergency.': 4.615032679738562,
#  'Climate emergency declarations have been made in 983 separate jurisdictions and local governments in 18 countries covering 212 million citizens.': 4.263888888888889,
#  'No scientific body of national or international standing disagrees with this view.': 1.2166666666666668,
#  'Scientific discussion takes place in journal articles that are peer-reviewed, which scientists subject to assessment every couple of years in the Intergovernmental Panel on Climate Change reports.': 5.255012077294686,
#  'National science academies have called on world leaders for policies to cut global emissions.': 3.3452898550724637,
#  'The report said that preventing such crises will require a swift transformation of the global economy that has "no documented historic precedent".': 3.4651570048309184,
#  'The global warming problem came to international public attention in the late 1980s.': 3.372101449275363,
#  'Significant regional differences exist in how concerned people are about climate change and how much they understand the issue.': 4.324999999999999,
#  'Public reactions to global warming and concern about its effects have been increasing, with many perceiving it as the worst global threat.': 5.2375,
#  'Due to confusing media coverage in the early 1990s, issues such as ozone depletion and climate change were often mixed up, affecting public understanding of these issues.': 5.502536231884059,
#  'Although there are a few areas of linkage, the relationship between the two is weak.': 1.268627450980392,
#  'From about 1990 onward, American conservative think tanks had begun challenging the legitimacy of global warming as a social problem.': 3.391666666666667,
#  'Additional disputes concern estimates of climate sensitivity, predictions of additional warming, what the consequences of global warming will be, and what to do about it.': 5.190338164251208,
#  'In general, since the 2010s, global oil companies do not dispute that climate change exists and is caused by the burning of fossil fuels.': 5.251388888888889,
#  'Mass civil disobedience actions by Extinction Rebellion and Ende Gelände have ended in police intervention and large-scale arrests.': 1.9638888888888888,
#  'In Greco-Roman geography, climate was thought to be simply set by klima, the angle of the midday sun defining bands of latitude which suited different peoples.': 4.592391304347826,
#  'Theophrastus thought agriculture caused local climate changes.': 2.6805555555555554,
#  'Colonists expected North America weather to match latitudes, but found winters unexpectedly harsh.': 3.8019607843137253,
#  'Colonists including Thomas Jefferson began research to confirm this warming.': 2.8296462063086105,
#  'Savants thought the earth had incandescent origins; in 1778 Buffon proposed climatic Epochs of diminishing warmth, shown by fossils of tropical animals found in subarctic zones.': 4.458333333333334,
#  'Edme Mariotte had noted in 1681 that glass let through the warmth of sunlight but obstructed radiant heat.': 3.0416666666666665,
#  'The warmed surface emits infrared radiation, but the atmosphere is relatively opaque to infrared and slows the emission of energy, warming the planet.': 5.646376811594203,
#  "[full citation needed] He also calculated that earth's cooling from a molten state had slowed over time.": 3.3051932367149757,
#  'Adolphe Brongniart found fossils of luxuriant tropical vegetation in coal seams, suggesting widespread warmth and higher levels of carbon dioxide during the Carboniferous.': 4.827234299516909,
#  "Eunice Foote's 1856 experiments used glass cylinders filled with different gases heated by sunlight (which could not distinguish the infrared greenhouse effect).": 7.091666666666667,
#  'Moist air warmed more than dry air; CO2 warmed most, so she concluded higher levels of this in the past would have increased temperatures.': 5.804528985507246,
#  "In the 1830s Melloni combined Seebeck's thermopile with a galvanometer to measure radiant heat transmission through air.": 2.5054347826086953,
#  'In 1839 he noticed variations which he thought might be due to changing proportions of water vapour amounts, but did not experiment on this.': 3.6092995169082127,
#  'He found that this increased with concentration of these gases up to a point when the effect became saturated.': 4.383333333333334,
#  'His 1861 paper proposed changing concentrations of these gases could have caused "all the mutations of climate which the researches of geologists reveal" and explain ice age changes.': 6.408212560386473,
#  'Water vapour appeared to be the main factor, his subsequent thermal research focussed on molecular physics and meteorology.': 3.5956521739130434,
#  'By then, as Humboldt noted in 1850, decades of climate measurements showed stability in North America rather than the expected improvement.': 4.1,
#  'Popular belief that rain follows the plow was dismissed by Cleveland Abbe in 1889.': 1.1916666666666667,
#  'Svante Arrhenius sought a mechanism causing ice ages, starting with the understanding that water vapour in air continuously varied, but carbon dioxide came from long term geological processes.': 5.9303743961352655,
#  'Warming from increased CO2 would increase the amount of water vapour, amplifying its effect in a feedback process.': 6.4012077294686,
#  'In 1896, after laborious calculations, he published the first climate model of its kind, showing that halving of CO2 could have produced the ice age drop in temperature.': 5.320591787439613,
#  'His source for geology, Arvid Högbom, had estimated industrial carbon output.': 2.355658567774936,
#  'From this, Arrhenius calculated the temperature increase from doubling CO2.': 1.2916666666666667,
#  'Other scientists highlighted flaws; Ångström said that saturation of the greenhouse effect meant adding more CO2 made no difference.': 4.635205314009662,
#  'Experts expected climate would be self-regulating.': 2.975,
#  'From 1938 Guy Stewart Callendar published evidence that climate was warming and CO2 levels increasing, but his calculations met the same objections.': 5.044444444444444,
#  'In the 1950s military research provided new data, showing less saturation of the greenhouse effect at high altitudes.': 5.1556159420289855,
#  'Earlier calculations had treated the atmosphere as a single layer, Gilbert Plass used digital computers to model the different layers and found added CO2 would cause warming.': 6.6,
#  "Revelle, Plass and other scientists alerted media to press for government attention, the dangers of global warming came to the fore at James Hansen's 1988 Congressional testimony.": 5.614371980676328,
#  'Research in the 1950s suggested that temperatures were increasing, and a 1952 newspaper used the term "climate change".': 5.033333333333333,
#  'A 1971 MIT report referred to the human impact as "inadvertent climate modification", identifying many possible causes.': 3.705555555555556,
#  'The phrase began to come into common use, and in 1976 Mikhail Budyko\'s statement that "a global warming up has started" was widely reported.': 3.7108695652173913,
#  "There were increasing heatwaves and drought problems in the summer of 1988, and NASA climate scientist James Hansen's testimony in the U.S. Senate sparked worldwide interest.": 4.472222222222221,
#  'Public attention increased over the summer, and global warming became the dominant popular term, commonly used both by the press and in public discourse.': 5.558333333333334,
#  'In the 2000s, the term climate change increased in popularity.': 3.216666666666667,
#  'People who regard climate change as catastrophic, irreversible, or rapid might label climate change as a climate crisis or a climate emergency.': 9.51388888888889,
#  'One newspaper, The Guardian, has embraced this terminology (as well as global heating) in their editorial guidelines.': 2.4499999999999997}

# %%
# get best sentences
best_sentences =heapq.nlargest(5,sent2score, key=sent2score.get)

# %%
best_sentences
# Out:
# ['People who regard climate change as catastrophic, irreversible, or rapid might label climate change as a climate crisis or a climate emergency.',
#  'Regions dependent on glacier water, regions that are already dry, and small islands are also at increased risk of water stress due to climate change.',
#  'Climate change can be mitigated through the reduction of greenhouse gas emissions or the enhancement of the capacity of carbon sinks to absorb greenhouse gases from the atmosphere.',
#  'One potential source of abrupt climate change would be the rapid release of methane and carbon dioxide from permafrost, which would amplify global warming.',
#  'Abrupt climate change, tipping points in the climate system: Climate change could result in global, large-scale changes.']
